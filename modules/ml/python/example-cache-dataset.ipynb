# %%
import numpy as np
from sklearn.datasets import make_regression
from sklearn.datasets import make_classification

from ggml.core import Ignite
from ggml.model_selection import train_test_split as ignite_train_test_split

# %%
with Ignite("/home/gridgain/ignite/examples/config/example-ignite.xml") as ignite:
    xy = np.column_stack(make_regression(n_targets=1))
    cache = ignite.create_cache("test-regression", parts=1)
    for i in range(xy.shape[0]):
        cache.put(i, xy[i])
        
    train_cache, test_cache = ignite_train_test_split(cache)
        
    dataset = test_cache.head(5)

dataset
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.255111  0.950447  2.132426  0.261376  0.113134 -0.180779  0.821647
# 1 -0.273304  0.944045 -0.079812 -0.560174 -0.425879 -1.964484  0.886530
# 2 -0.078458  1.142649 -0.325323  1.758534  0.333253  0.799614 -0.778235
# 3  1.649227  0.850419 -0.645858 -0.484287 -0.925275 -0.610341  1.252078
# 4  0.338205 -2.032395  1.885124  0.581841 -1.358230  0.894671  0.602407
#
#         7         8         9       ...           91        92        93   \
# 0 -0.296695 -0.248567 -0.309934     ...     -0.516908  0.232551  0.653376
# 1  0.316109 -0.183243  0.198578     ...     -0.939244  0.020432  0.503070
# 2 -0.453308 -0.522046  0.799447     ...      0.710498 -0.795295 -1.743009
# 3 -2.196809 -0.450300  2.177981     ...     -1.158623  1.044376  1.745838
# 4  0.635697 -0.467694  1.041598     ...     -1.021847 -0.395385  0.854698
#
#         94        95        96        97        98        99          100
# 0 -0.393577 -0.084246  0.068190 -1.608083 -0.857543 -1.690616 -205.283403
# 1  0.434385 -0.797680  0.340512 -0.666481  0.739698  0.188225  304.189681
# 2  0.977579 -2.100447  0.072374  0.001802 -0.318640  0.002941  318.773679
# 3 -0.952002  2.685574 -1.747800  0.979639  0.971613  0.376180  -41.658825
# 4 -2.146657  2.035811  0.682407 -0.306598  2.836391  0.433500 -435.369364
#
# [5 rows x 101 columns]

# %%
x, y = make_classification()
xy = np.column_stack((x, y))

# %%
from ggml.preprocessing import NormalizationTrainer

with Ignite("/home/gridgain/ignite/examples/config/example-ignite.xml") as ignite:
    cache = ignite.create_cache("test-42")
    for i in range(xy.shape[0]):
        cache.put(i, xy[i])
    
    train_cache, test_cache = ignite_train_test_split(cache)
    
    normalizer = NormalizationTrainer().fit_on_cache(train_cache)
    
    dataset_1 = test_cache.head()
    dataset_2 = test_cache.transform(normalizer).head()

# %%
dataset_1
# Out:
#          0         1         2         3         4         5         6   \
# 0 -2.223173  0.600548 -0.991743 -0.905016  0.095458  0.416760 -0.109526
# 1  1.453267 -0.570561  0.197515 -0.761859 -0.925908  0.404113  1.239926
# 2 -0.073048  0.055805  0.241635 -0.264198 -0.584125  2.808151  0.763340
# 3  0.288882 -0.228471  1.544083 -1.130976  0.918953  1.300618  0.413818
# 4  0.477468 -0.421290  0.148834 -1.426855 -1.804560 -1.802442  0.374855
#
#          7         8         9  ...         11        12        13        14  \
# 0 -0.858041 -0.145816 -0.344704 ...  -0.372797 -0.004418  0.794898 -0.169134
# 1  0.674759 -0.336182  0.829135 ...  -0.454678  0.767006  0.804430  0.803125
# 2 -1.390630 -0.183467  1.356631 ...  -0.762358 -2.188540 -0.141963 -0.145917
# 3  0.801285 -1.734627  4.183758 ...   0.758186  1.839523 -0.034558  0.607326
# 4  0.887189  0.278378 -0.000575 ...   0.182761  0.177287  0.225452  1.173722
#
#          15        16        17        18        19   20
# 0  0.162666  0.366214 -0.136944  0.493256 -0.216652  0.0
# 1 -0.346030  0.796023 -0.065367 -0.470655 -0.668327  1.0
# 2  0.568706  0.795772  2.184030  1.222483  0.157032  0.0
# 3 -0.159996  0.494532 -1.603282 -0.265024 -0.656411  1.0
# 4  0.037333 -1.736204  0.568059  1.369410 -1.283651  1.0
#
# [5 rows x 21 columns]

# %%
dataset_2
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.723305  0.195387 -0.322662 -0.294445  0.031057  0.135592 -0.035634
# 1  0.448511 -0.176088  0.060958 -0.235127 -0.285756  0.124718  0.382669
# 2 -0.014346  0.010959  0.047454 -0.051885 -0.114715  0.551485  0.149910
# 3  0.047537 -0.037596  0.254089 -0.186109  0.151220  0.214025  0.068097
# 4  0.111462 -0.098348  0.034745 -0.333092 -0.421265 -0.420771  0.087508
#
#          7         8         9  ...         11        12        13        14  \
# 0 -0.279162 -0.047441 -0.112149 ...  -0.121289 -0.001438  0.258619 -0.055027
# 1  0.208246 -0.103753  0.255890 ...  -0.140324  0.236716  0.248265  0.247863
# 2 -0.273102 -0.036031  0.266425 ...  -0.149718 -0.429802 -0.027880 -0.028656
# 3  0.131857 -0.285444  0.688465 ...   0.124764  0.302705 -0.005687  0.099940
# 4  0.207110  0.064986 -0.000134 ...   0.042665  0.041387  0.052631  0.274000
#
#          15        16        17        18        19   20
# 0  0.052923  0.119147 -0.044555  0.160480 -0.070487  0.0
# 1 -0.106793  0.245671 -0.020174 -0.145255 -0.206261  1.0
# 2  0.111687  0.156279  0.428916  0.240080  0.030839  0.0
# 3 -0.026328  0.081379 -0.263831 -0.043611 -0.108017  1.0
# 4  0.008715 -0.405308  0.132610  0.319682 -0.299662  1.0
#
# [5 rows x 21 columns]

# %%
from ggml.preprocessing import NormalizationTrainer

with Ignite("/home/gridgain/ignite/examples/config/example-ignite.xml") as ignite:
    cache = ignite.create_cache("test-42")
    for i in range(xy.shape[0]):
        cache.put(i, xy[i])
    
    res = cache[1:10]
    
res[0:2]
# Out:
# array([[-1.41919556,  0.6731509 , -1.54150079,  0.20264187, -0.99018827,
#         -0.09549558,  2.27916648,  0.55989356, -0.71159814, -1.6130995 ,
#         -0.22698942, -1.1165692 , -0.34043841, -1.05044541, -1.23552519,
#         -0.42986369,  0.61253389,  1.12083497,  1.32915684,  1.18036934,
#          0.        ],
#        [-0.55246785,  0.34047071,  0.63643098,  0.29097855, -0.69594171,
#          1.92516344, -0.17675325, -2.94403941, -2.23859733,  0.59298653,
#          0.04751614, -1.28394995, -1.03323938, -0.72883277, -0.78612331,
#         -0.79202089,  0.86994422, -0.66875224, -0.19630317,  0.81637461,
#          0.        ]])

# %%
from ggml.preprocessing import NormalizationTrainer

with Ignite("/home/gridgain/ignite/examples/config/example-ignite.xml") as ignite:
    cache = ignite.create_cache("test-42")
    for i in range(xy.shape[0]):
        cache.put(i, xy[i])
    
    train_cache, test_cache = ignite_train_test_split(cache)
    
    normalizer = NormalizationTrainer().fit_on_cache(train_cache)
    
    dataset_1 = test_cache.head()
    dataset_2 = test_cache.transform(normalizer).head()
